# %%
"hello world"
# Out:
# 'hello world'

# %%
print("hello world")
# Out:
# hello world

# %%
name = "görkem"

# %%
type(name) #str : string
# Out:
# str

# %%
name
# Out:
# 'görkem'

# %%
print(name) #Böyle yazmaya alış
# Out:
# görkem

# %%
'brainApp Uygulaması'
# Out:
# 'brainApp Uygulaması'

# %%
name.capitalize() #stringteki ilk baş harfi büyük yapar
# Out:
# 'Görkem'

# %%
name.count("e")  #belirtilen harften stringte kaç tane olduğunu yazdırır
# Out:
# 1

# %%
help(name.find)
# Out:
# Help on built-in function find:
#
# find(sub[, start[, end]], /) method of builtins.str instance
#     Return the lowest index in S where substring sub is found, such that sub is contained within S[start:end].
#
#     Optional arguments start and end are interpreted as in slice notation.
#     Return -1 on failure.

# %%
name.find("g")
# Out:
# 0

# %%
name.find("m")
# Out:
# 5

# %%
name.find("a") #returns -1
# Out:
# -1

# %%
print(name.upper())
# Out:
# GÖRKEM

# %%
print(name.split("ö"))
# Out:
# ['g', 'rkem']

# %%
print(name.split("k"))
# Out:
# ['gör', 'em']

# %%
print(name.split())
# Out:
# ['görkem']

# %%
print(name.strip("m"))
# Out:
# görke

# %%
help(name.strip)
# Out:
# Help on built-in function strip:
#
# strip(chars=None, /) method of builtins.str instance
#     Return a copy of the string with leading and trailing whitespace removed.
#
#     If chars is given and not None, remove characters in chars instead.

# %%
print(name.index("e"))
# Out:
# 4

# %%
new_name = name.upper()

# %%
print(new_name)
# Out:
# GÖRKEM

# %%
print(len(name))  #length of string
# Out:
# 6

# %%
print("Görkem \nÖnder") # \n : newline - escape character
# Out:
# Görkem
# Önder

# %%
print("Görkem \tÖnder")  # \₺ : tab -  escape character
# Out:
# Görkem 	Önder

# %%
name_2 = "Sinem"

# %%
name_2
# Out:
# 'Sinem'

# %%
name_2  = name_2.upper()

# %%
name_2
# Out:
# 'SINEM'

# %%
#INDEX

# %%
myName = "Görkem"

# %%
myName[0]
# Out:
# 'G'

# %%
myName[4]
# Out:
# 'e'

# %%
myName[0:]
# Out:
# 'Görkem'

# %%
myName[-6:]
# Out:
# 'Görkem'

# %%
myName[0: : 2] #en baştan en sona kadar, 2 şer 2 şer...
# Out:
# 'Gre'

# %%
myName[len(myName) - 1]
# Out:
# 'm'
