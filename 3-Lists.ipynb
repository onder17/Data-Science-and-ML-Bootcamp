# %%
x = int(input("Please enter the value for x: "))
# Out:
# Please enter the value for x:  10

# %%
y = int(input("Please enter the value for y: "))
z = int(input("Please enter the value for z: "))
# Out:
# Please enter the value for y:  20
# Please enter the value for z:  30

# %%
myList = [x , y , z]

# %%
myList
# Out:
# [10, 20, 30]

# %%
myList.append(x + y + z)

# %%
myList
# Out:
# [10, 20, 30, 60]

# %%
myList.pop()
# Out:
# 60

# %%
myList
# Out:
# [10, 20, 30]

# %%
myList.append(x)
myList.append(y)
myList.append(z)

# %%
myList
# Out:
# [10, 20, 30, 10, 20, 30]

# %%
myList[0:3]
# Out:
# [10, 20, 30]

# %%
myList[1] * 10
# Out:
# 200

# %%
myList
# Out:
# [10, 20, 30, 10, 20, 30]

# %%
i = 0
while i < len(myList):
    print(myList[i] * 10)
    i += 1
# Out:
# 100
# 200
# 300
# 100
# 200
# 300
