# %%
1900+5
# Out:
# 1905

# %%
6*8
# Out:
# 48

# %%
6*8
# Out:
# 48

# %%
age = 30

# %%
age
# Out:
# 30

# %%
age * 5
# Out:
# 150

# %%
type(age)
# Out:
# int

# %%
age = 20.5

# %%
type(age)
# Out:
# float

# %%
#data_type

# %%
new_value = age / 2

# %%
new_value
# Out:
# 10.25

# %%
age = 30

# %%
new_value = age / 2

# %%
new_value
# Out:
# 15.0

# %%
type(new_value)
# Out:
# float

# %%
int(new_value)
# Out:
# 15

# %%
3 ** 4 #four power of three
# Out:
# 81

# %%
106 % 4 #mode,remainder
# Out:
# 2

# %%
process = 10 / 2

# %%
process
# Out:
# 5.0

# %%
type(process)
# Out:
# float

# %%
int(process)
# Out:
# 5

# %%
type(int(process))
# Out:
# int

# %%
type(process)
# Out:
# float

# %%
2 * 2 * 2 * 2 * 2
# Out:
# 32

# %%
2 ** 5
# Out:
# 32

# %%
pow(2,5)
# Out:
# 32
